# %% [markdown]
# # parcer v5
# new parcer is nice to combine several different logs from different sources into one plot
# nicely works in jupyter

# %%
# %run ../python/pyparser/nmlogparcer_v5.py -h
# Out:
# usage: nmlogparcer [-h] [-if [INPUTFILE]] [-of [OUTPUTFILE]]
#                    [--format [FORMAT]] [-fs [FIGSIZE]] [-k [KEY]]
#                    [-d [DELIMETER]] [--figuretitle [FIGURETITLE]]
#                    [--subtitle [SUBTITLE]] [--labely [LABELY]]
#                    [--labelx [LABELX]] [--logy] [--logx] [--ylim [YLIM]]
#                    [--xlim [XLIM]] [--timex] [--timeshift [TIMESHIFT]]
#                    [--zero] [--fin] [--rmdt_negativekey [RMDT_NEGATIVEKEY]]
#                    [--rmdt_mainpattern [RMDT_MAINPATTERN]]
#                    [--rmdt_idpattern [RMDT_IDPATTERN]]
#                    [--outputfile_dpi [OUTPUTFILE_DPI]] [--streamid [STREAMID]]
#                    [--linewidth [LINEWIDTH]] [--linestyle [LINESTYLE]]
#                    [--linemarker [LINEMARKER]]
#                    [--linemarkersize [LINEMARKERSIZE]] [--hline [HLINE]]
#                    [--linecolor [LINECOLOR]] [--legendtoright]
# ...

# %%
# %run ../python/pyparser/nmlogparcer_v5.py -if ../data/iperf3/iperf_ger_plain.txt --format IPERF -k Transfer --zero --timeshift 15
# %run ../python/pyparser/nmlogparcer_v5.py -if ../data/iperf3/iperf_ger_plain_V.txt --format IPERF -k Bitrate --zero --timeshift 15
# %run ../python/pyparser/nmlogparcer_v5.py -if ../data/iperf3/iperf_fra_plain.txt --format IPERF -k Retr --zero --timeshift 15
# %run ../python/pyparser/nmlogparcer_v5.py -if ../data/iperf3/iperf_fra_plain_V.txt --format IPERF -k Cwnd --zero --timeshift 15 --fin

# %% [markdown]
# # a lot of different sources in several plots

# %%
# %run ../python/pyparser/nmlogparcer_v5.py -if ../data/iperf3/iperf_fra_json_V.json --format IPERF_JSON -k bits_per_second --timeshift 7200 --labely iperfR12
# %run ../python/pyparser/nmlogparcer_v5.py -if ../data/iperf3/iperf_ger_json_V.json --format IPERF_JSON -k bits_per_second --timeshift 7200 --labely iperfR22
# %run ../python/pyparser/nmlogparcer_v5.py -fs 24,6 --xlim 7150,7300 --ylim 9e1,11e8 --labely atata --subtitle wakawaka --fin 
# %run ../python/pyparser/nmlogparcer_v5.py -if ../data/iperf3/iperf_ger_plain.txt --format IPERF -k Bitrate -d 0.000001 --figuretitle 2  --labely brate  --zero --timeshift 7200
# %run ../python/pyparser/nmlogparcer_v5.py -if ../data/iperf3/iperf_fra_json.json --format IPERF_JSON -k bits_per_second --figuretitle 2  --labely iperfR11 --zero --timeshift 7200
# %run ../python/pyparser/nmlogparcer_v5.py -if ../data/iperf3/iperf_ger_json.json --format IPERF_JSON -k bits_per_second --figuretitle 2  --labely iperfR21 --zero --timeshift 7200
# %run ../python/pyparser/nmlogparcer_v5.py --figuretitle 2 --outputfile_dpi 121 -fs 24,12  --fin
